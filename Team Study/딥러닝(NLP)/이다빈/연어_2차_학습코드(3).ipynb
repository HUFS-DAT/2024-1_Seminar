# %% [markdown]
# # 합성곱 신경망(Convolution Neural Network)
#
# - 이미지 인식, 음성 인식 등에 자주 사용되는데,
#   특히, 이미지 인식 분야에서 거의 모든 딥러닝 기술에 사용
#
# <br>
#
# ## 컨볼루션 신경망의 등장
# - 1989년 얀 르쿤(Yann LeCun) 교수의 논문에서 발표
#
#   - 필기체 인식에서 의미가 있었지만 범용화하는데에는 무리
#
# - 1998년, "Gradient-Based Learning Applied to Document Recognition"이라는 논문에서 LeNet-5 제시
#
# - 합성곱 층(convolution layer), 풀링 층(pooling layer) 소개
#   <br>
#
#   <img src="https://miro.medium.com/max/4308/1*1TI1aGBZ4dybR6__DI9dzA.png">
#
#   <center>[LeNet-5 구조]</center>
#
#   <sub>출처: https://medium.com/@pechyonkin/key-deep-learning-architectures-lenet-5-6fc3c59e6f4</sub>

# %% [markdown]
# ## 컨볼루션 신경망 구조 예시
#
# <img src="https://www.oreilly.com/api/v2/epubs/9781789138900/files/assets/c38754ca-f2ea-425a-b7a6-1fe0f2f5074e.png" width="600">
#
# <sub>출처: https://www.oreilly.com/library/view/neural-network-projects/9781789138900/8e87ad66-6de3-4275-81a4-62b54436bf16.xhtml</sub>

# %% [markdown]
# ## 합성곱 연산
# - 필터(filter) 연산
#   - 입력 데이터에 필터를 통한 어떠한 연산을 진행
#
#   - **필터에 대응하는 원소끼리 곱하고, 그 합을 구함**
#
#   - 연산이 완료된 결과 데이터를 **특징 맵(feature map)**이라 부름
#
# - 필터(filter)
#   - 커널(kernel)이라고도 칭함
#
#   - 흔히 사진 어플에서 사용하는 '이미지 필터'와 비슷한 개념
#
#   - 필터의 사이즈는 "거의 항상 홀수"
#     - 짝수이면 패딩이 비대칭이 되어버림
#
#     - 왼쪽, 오른쪽을 다르게 주어야함
#
#     - 중심위치가 존재, 즉 구별된 하나의 픽셀(중심 픽셀)이 존재
#
#   - 필터의 학습 파라미터 개수는 입력 데이터의 크기와 상관없이 일정
#     따라서, 과적합을 방지할 수 있음
#
#   <br>
#   <img src="https://blog.kakaocdn.net/dn/p4Z5K/btrqmpAF2xM/PP1It1nt2HnsaQi0WsqDL0/img.gif">
#
#   <sub>출처: http://deeplearning.net/software/theano_versions/dev/tutorial/conv_arithmetic.html</sub>
#
#
# - 연산 시각화
#   <img src="https://www.researchgate.net/profile/Ihab_S_Mohamed/publication/324165524/figure/fig3/AS:611103423860736@1522709818959/An-example-of-convolution-operation-in-2D-2.png" width="500">
#
#   <sub>출처: https://www.researchgate.net/figure/An-example-of-convolution-operation-in-2D-2_fig3_324165524</sub>
#
#
# - 일반적으로, 합성곱 연산을 한 후의 데이터 사이즈는
#   ### $\quad (n-f+1) \times (n-f+1)$
#     $n$: 입력 데이터의 크기
#     $f$: 필터(커널)의 크기
#
#
#   <img src="https://blog.kakaocdn.net/dn/cq3baG/btrp66o6dmu/1sHE3XQNMkA5Napixjkvb0/img.gif" width="400">
#
#   <sub>출처: https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1</sub>
#
#   위 예에서 입력 데이터 크기($n$)는 5, 필터의 크기($k$)는 3이므로
#   출력 데이터의 크기는 $(5 - 3 + 1) = 3$

# %% [markdown]
# ## 패딩(padding)과 스트라이드(stride)
# - 필터(커널) 사이즈과 함께 **입력 이미지와 출력 이미지의 사이즈를 결정**하기 위해 사용
#
# - 사용자가 결정할 수 있음

# %% [markdown]
# ### 패딩
# - 입력 데이터의 주변을 특정 값으로 채우는 기법
#   - 주로 0으로 많이 채움
#
#   <img src="https://blog.kakaocdn.net/dn/bM0p6P/btrqkT252cb/rTe9UgfyDeFCRKkABVi8sk/img.gif" width="300">
#
# - 출력 데이터의 크기
#   ### $\quad (n+2p-f+1) \times (n+2p-f+1)$
#
#   위 그림에서, 입력 데이터의 크기($n$)는 5, 필터의 크기($f$)는 4, 패딩값($p$)은 2이므로
#   출력 데이터의 크기는 ($5 + 2\times 2 - 4 + 1) = 6$
#
# ### 'valid' 와 'same'
# - 'valid'
#   - 패딩을 주지 않음
#   - padding=0 (0으로 채워진 테두리가 아니라 패딩을 주지 않는다는 의미)
#
# - 'same'
#   - 패딩을 주어 입력 이미지의 크기와 연산 후의 이미지 크기를 같게함
#
#   - 만약, 필터(커널)의 크기가 $k$ 이면,
#     패딩의 크기는 $p = \frac{k-1}{2}$ (단, <u>stride=1)</u>

# %% [markdown]
# ### 스트라이드
# - 필터를 적용하는 간격을 의미
#
# - 아래는 그림의 간격 2
#
#   <img src="https://blog.kakaocdn.net/dn/0eMlG/btrqiqNt5dy/BexNsUvqgdflkiIC3pJIaK/img.gif">

# %% [markdown]
# ## 출력 데이터의 크기
#
# ## $\qquad OH = \frac{H + 2P - FH}{S} + 1 $
# ## $\qquad OW = \frac{W + 2P - FW}{S} + 1 $
#
# - 입력 크기 : $(H, W)$
#
# - 필터 크기 : $(FH, FW)$
#
# - 출력 크기 : $(OH, OW)$
#
# - 패딩, 스트라이드 : $P, S$
#
# - (주의)
#   - 위 식의 값에서 $\frac{H + 2P - FH}{S}$ 또는 $\frac{W + 2P - FW}{S}$가 정수로 나누어 떨어지는 값이어야 함
#   - 만약, 정수로 나누어 떨어지지 않으면
#     패딩, 스트라이드값을 조정하여 정수로 나누어 떨어지게 해야함

# %% [markdown]
# ## 풀링(Pooling)
#
# - 필터(커널) 사이즈 내에서 특정 값을 추출하는 과정

# %% [markdown]
# ### 맥스 풀링(Max Pooling)
# - 가장 많이 사용되는 방법
#
# - 출력 데이터의 사이즈 계산은 컨볼루션 연산과 동일
# ## $\quad OH = \frac{H + 2P - FH}{S} + 1 $
# ## $\quad OW = \frac{W + 2P - FW}{S} + 1 $
#
# - 일반적으로 stride=2, kernel_size=2 를 통해
#   **특징맵의 크기를 <u>절반으로 줄이는 역할</u>**
#
# - 모델이 물체의 주요한 특징을 학습할 수 있도록 해주며,
#   컨볼루션 신경망이 이동 불변성 특성을 가지게 해줌
#   - 예를 들어, 아래의 그림에서 초록색 사각형 안에 있는
#     2와 8의 위치를 바꾼다해도 맥스 풀링 연산은 8을 추출
#
# - 모델의 파라미터 개수를 줄여주고, 연산 속도를 빠르게 해줌
#
#   <br>
#
#   <img src="https://cs231n.github.io/assets/cnn/maxpool.jpeg" width="600">
#
#   <sub>출처: https://cs231n.github.io/convolutional-networks/</sub>

# %% [markdown]
# ## Conv1D
# #### 자연어처리에서는 2D보다 1D 많이 사용한다!
# - 텍스트 분류나 시계열 예측 같은 간단한 문제, 오디오 생성, 기계 번역 등의 문제에서 좋은 성능
#
# - 타임스텝의 순서에 민감하지 X
#
#
# - 2D Convolution
#   - 지역적 특징을 인식
#
#   <img src="https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2Fb6cWoA%2Fbtrp8hRnCvp%2FZHggIXjiUl0RX69PQujvdk%2Fimg.png" width="500">
#
# - 1D Convolution
#   - 문맥을 인식
#
#   <img src="https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FcMHTA5%2FbtrqptbfUmy%2F1zpGOrhCf3Ou9pn2zlZMLK%2Fimg.png" width="500">
#
#   <sub>출처: https://missinglink.ai/guides/keras/keras-conv1d-working-1d-convolutional-neural-networks-keras/</sub>

# %% [markdown]
# ### Conv1D Layer
# - 입력: `(batch_size, timesteps, channels)`
#
# - 출력: `(batch_size, timesteps, filters)`
#
# - 필터의 사이즈가 커져도 모델이 급격히 증가하지 않기 때문에 다양한 크기를 사용할 수 있음
# - 데이터의 품질이 좋으면 굳이 크기를 달리하여 여러 개를 사용하지 않아도 될 수도 있음

# %% [markdown]
# ### MaxPooling1D Layer
# - 다운 샘플링 효과
#
# - 단지 1차원형태로 바뀐 것 뿐

# %% [markdown]
# ### GlobalMaxPooling Layer
# - 배치차원을 제외하고 2차원 형태를 1차원 형태로 바꾸어주는 레이어
#
# - Flatten layer로 대신 사용가능

# %% [markdown]
# ## IMDB 데이터

# %% [markdown]
# ### 데이터 로드 및 전처리

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Dense, Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D

# %%
num_words = 10000
max_len = 500
batch_size = 32

(input_train,y_train), (input_test, y_test) = imdb.load_data(num_words=num_words)

print(len(input_train))
print(len(input_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step
# 25000
# 25000

# %%
pad_x_train = pad_sequences(input_train, maxlen=max_len)
pad_x_test = pad_sequences(input_test, maxlen = max_len)

print(pad_x_train.shape)
print(pad_x_test.shape)
# Out:
# (25000, 500)
# (25000, 500)

# %% [markdown]
# ### 모델 구성

# %%
def build_model():
  model = Sequential()

  model.add(Embedding(input_dim = num_words, output_dim =32, input_length=max_len))
  model.add(Conv1D(32, 7, activation='relu'))
  model.add(MaxPooling1D(7))
  model.add(Conv1D(32, 5, activation='relu'))
  model.add(MaxPooling1D(5))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(1, activation='sigmoid'))

  model.compile(optimizer=RMSprop(learning_rate=1e-4),
                loss='binary_crossentropy',
                metrics=['accuracy'])
  return model

# 경사 하강법(Gradient Descent)의 한 종류로, 학습률(learning rate)을 조절하여 모델의 가중치를 업데이트하는 방식을 제어합니다.
# RMSprop은 주로 순환 신경망(RNN)과 같은 시계열 데이터를 다루는데 특히 유용

# %% [markdown]
# ---
#
#
# #### Embedding 레이어:
# - 입력으로 정수로 인코딩된 단어를 받고, 각 단어 인덱스를 입력된 벡터로 변환
# - input_dim은 단어 집합(vocabulary)의 크기를 나타냅니다.
# - output_dim은 임베딩 벡터의 차원을 나타냅니다.
# - input_length는 입력 시퀀스의 길이를 나타냅니다.
#
# #### Conv1D 레이어:
# - 1차원 합성곱(Conv1D) 레이어를 추가
# - 32개의 필터를 사용하며, 각 필터의 크기는 7
# - 활성화 함수로는 ReLU(Rectified Linear Unit)를 사용
#
# #### MaxPooling1D 레이어:
# - 1차원 최대 풀링(MaxPooling1D) 레이어를 추가
# - 풀링 윈도우 크기는 7로 설정
#
# ####추가 Conv1D 및 MaxPooling1D 레이어:
# - 위의 과정을 반복하여 두 번째 Conv1D 레이어와 MaxPooling1D 레이어를 추가
#
# #### GlobalMaxPooling1D 레이어:
# - 전역 최대 풀링(GlobalMaxPooling1D) 레이어를 추가
# - 각 필터에 대해 최대값을 취한 후 결과를 모두 하나의 벡터로 합칩니다.
#
# #### Dense 레이어:
# - 이진 분류를 위한 출력 레이어로 Dense 레이어를 추가
# - 활성화 함수로는 시그모이드 함수를 사용하여 이진 분류를 수행
#
# #### 모델 컴파일:
# - RMSprop 옵티마이저를 사용하여 모델을 컴파일
# - 손실 함수로는 이진 분류(binary_crossentropy)를 사용
# - 평가 지표(metrics)로는 정확도(accuracy)를 사용
#
# ---

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 500, 32)           320000
#
#  conv1d_2 (Conv1D)           (None, 494, 32)           7200
#
#  max_pooling1d_2 (MaxPoolin  (None, 70, 32)            0
#  g1D)
#
#  conv1d_3 (Conv1D)           (None, 66, 32)            5152
#
#  max_pooling1d_3 (MaxPoolin  (None, 13, 32)            0
#  g1D)
#
#  global_max_pooling1d (Glob  (None, 32)                0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 332385 (1.27 MB)
# Trainable params: 332385 (1.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습

# %%
history = model.fit(pad_x_train, y_train,
                    batch_size = 128, epochs=30,
                    validation_split=0.2)
# Out:
# Epoch 1/30
# 157/157 [==============================] -
# Epoch 25/30
# 157/157 [==============================] - 20s 130ms/step - loss: 0.1985 - accuracy: 0.9291 - val_loss: 0.3398 - val_accuracy: 0.8636
# Epoch 26/30
# 157/157 [==============================] - 22s 140ms/step - loss: 0.1912 - accuracy: 0.9329 - val_loss: 0.3426 - val_accuracy: 0.8646
# Epoch 27/30
# 157/157 [==============================] - 18s 114ms/step - loss: 0.1839 - accuracy: 0.9348 - val_loss: 0.3446 - val_accuracy: 0.8628
# Epoch 28/30
# 157/157 [==============================] - 20s 128ms/step - loss: 0.1774 - accuracy: 0.9373 - val_loss: 0.3479 - val_accuracy: 0.8604
# Epoch 29/30
# 157/157 [==============================] - 18s 113ms/step - loss: 0.1710 - accuracy: 0.9403 - val_loss: 0.3534 - val_accuracy: 0.8604
# Epoch 30/30
# 157/157 [==============================] - 20s 127ms/step - loss: 0.1649 - accuracy: 0.9432 - val_loss: 0.3556 - val_accuracy: 0.8604

# %% [markdown]
# ### 시각화

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(1 , len(loss) +1)

plt.plot(epochs, loss, 'b--', label='training loss')
plt.plot(epochs, val_loss, 'r:', label='validation loss')
plt.grid()
plt.legend()

plt.figure()
plt.plot(epochs, acc, 'b--', label='training accuracy')
plt.plot(epochs, val_acc, 'r:', label='validation accuracy')
plt.grid()
plt.legend()

plt.show()

# 비교적 높은 성능을 보
# Out:
# <ipython-input-11-826ec8ea9f5e>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
model.evaluate(pad_x_test, y_test)
# Out:
# 782/782 [==============================] - 7s 9ms/step - loss: 0.3664 - accuracy: 0.8504
# [0.3663698732852936, 0.8504400253295898]

# %% [markdown]
# ## Reuters 데이터

# %% [markdown]
# ### 데이터 로드 및 전처리

# %%
from tensorflow.keras.datasets import reuters

# %%
num_words = 10000
max_len = 500

(input_train,y_train), (input_test, y_test) = reuters.load_data(num_words=num_words)

print(len(input_train))
print(len(input_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step
# 8982
# 2246

# %%
pad_x_train = pad_sequences(input_train, maxlen=max_len)
pad_x_test = pad_sequences(input_test, maxlen = max_len)

print(pad_x_train.shape)
print(pad_x_test.shape)
# Out:
# (8982, 500)
# (2246, 500)

# %% [markdown]
# ### 모델 구성

# %%
def build_model():
  model = Sequential()

  model.add(Embedding(input_dim = num_words, output_dim =64, input_length=max_len))
  model.add(Conv1D(64, 7, activation='relu'))
  model.add(MaxPooling1D(7))
  model.add(Conv1D(64, 5, activation='relu'))
  model.add(MaxPooling1D(5))
  model.add(GlobalMaxPooling1D())
  model.add(Dense(46, activation='softmax')) # reuters는 다중분류(46개 분류)

  model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 500, 64)           640000
#
#  conv1d_8 (Conv1D)           (None, 494, 64)           28736
#
#  max_pooling1d_8 (MaxPoolin  (None, 70, 64)            0
#  g1D)
#
#  conv1d_9 (Conv1D)           (None, 66, 64)            20544
#
#  max_pooling1d_9 (MaxPoolin  (None, 13, 64)            0
#  g1D)
#
#  global_max_pooling1d_3 (Gl  (None, 64)                0
#  obalMaxPooling1D)
#
#  dense_3 (Dense)             (None, 46)                2990
#
# =================================================================
# Total params: 692270 (2.64 MB)
# Trainable params: 692270 (2.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습

# %%
history = model.fit(pad_x_train, y_train,
                    batch_size = 128, epochs=30,
                    validation_split=0.2)
# Out:
# Epoch 1/30
# 57/57 [==============================] - 20s 329ms/step - loss: 2.6439 - accuracy: 0.3801 - val_loss: 1.9925 - val_accuracy: 0.5120
# Epoch 2/30
# 57/57 [==============================] - 17s 305ms/step - loss: 1.8324 - accuracy: 0.5255 - val_loss: 1.7003 - val_accuracy: 0.5403
# Epoch 3/30
# 57/57 [==============================] - 19s 341ms/step - loss: 1.6109 - accuracy: 0.5797 - val_loss: 1.5794 - val_accuracy: 0.6060
# Epoch 4/30
# 57/57 [==============================] - 17s 306ms/step - loss: 1.4238 - accuracy: 0.6534 - val_loss: 1.4589 - val_accuracy: 0.6516
# Epoch 5/30
# 57/57 [==============================] - 19s 332ms/step - loss: 1.2045 - accuracy: 0.7033 - val_loss: 1.3611 - val_accuracy: 0.6828
# Epoch 6/30
# 57/57 [==============================] - 18s 312ms/step - loss: 1.0073 - accuracy: 0.7432 - val_loss: 1.3161 - val_accuracy: 0.6978
# Epoch 7/30
# 57/57 [==============================] - 18s 311ms/step - loss: 0.8458 - accuracy: 0.7847 - val_loss: 1.3205 - val_accuracy: 0.7140
# Epoch 8/30
# 57/57 [==============================] - 19s 322ms/step - loss: 0.6957 - accuracy: 0.8257 - val_loss: 1.3604 - val_accuracy: 0.7262
# Epoch 9/30
# 57/57 [==============================] - 17s 306ms/step - loss: 0.5648 - accuracy: 0.8579 - val_loss: 1.3831 - val_accuracy: 0.7268
# Epoch 10/30
# 57/57 [==============================] - 19s 332ms/step - loss: 0.4712 - accuracy: 0.8820 - val_loss: 1.4388 - val_accuracy: 0.7385
# Epoch 11/30
# 57/57 [==============================] - 18s 312ms/step - loss: 0.3786 - accuracy: 0.9105 - val_loss: 1.5075 - val_accuracy: 0.7329
# Epoch 12/30
# 57/57 [==============================] - 19s 327ms/step - loss: 0.3197 - accuracy: 0.9260 - val_loss: 1.5706 - val_accuracy: 0.7262
# Epoch 13/30
# 57/57 [==============================] - 18s 312ms/step - loss: 0.2712 - accuracy: 0.9400 - val_loss: 1.6207 - val_accuracy: 0.7268
# Epoch 14/30
# 57/57 [==============================] - 20s 345ms/step - loss: 0.2328 - accuracy: 0.9496 - val_loss: 1.6718 - val_accuracy: 0.7407
# Epoch 15/30
# 57/57 [==============================] - 18s 309ms/step - loss: 0.1971 - accuracy: 0.9559 - val_loss: 1.7177 - val_accuracy: 0.7362
# Epoch 16/30
# 57/57 [==============================] - 19s 337ms/step - loss: 0.1796 - accuracy: 0.9592 - val_loss: 1.7398 - val_accuracy: 0.7407
# Epoch 17/30
# 57/57 [==============================] - 18s 313ms/step - loss: 0.1670 - accuracy: 0.9595 - val_loss: 1.8357 - val_accuracy: 0.7307
# Epoch 18/30
# 57/57 [==============================] - 19s 336ms/step - loss: 0.1459 - accuracy: 0.9631 - val_loss: 1.7969 - val_accuracy: 0.7268
# Epoch 19/30
# 57/57 [==============================] - 17s 306ms/step - loss: 0.1441 - accuracy: 0.9620 - val_loss: 1.8013 - val_accuracy: 0.7379
# Epoch 20/30
# 57/57 [==============================] - 18s 308ms/step - loss: 0.1500 - accuracy: 0.9620 - val_loss: 1.8364 - val_accuracy: 0.7212
# Epoch 21/30
# 57/57 [==============================] - 19s 324ms/step - loss: 0.1421 - accuracy: 0.9631 - val_loss: 1.8391 - val_accuracy: 0.7290
# Epoch 22/30
# 57/57 [==============================] - 18s 309ms/step - loss: 0.1237 - accuracy: 0.9614 - val_loss: 1.8522 - val_accuracy: 0.7340
# Epoch 23/30
# 57/57 [==============================] - 18s 325ms/step - loss: 0.1151 - accuracy: 0.9648 - val_loss: 1.8858 - val_accuracy: 0.7346
# Epoch 24/30
# 57/57 [==============================] - 18s 310ms/step - loss: 0.1212 - accuracy: 0.9628 - val_loss: 1.8862 - val_accuracy: 0.7290
# Epoch 25/30
# 57/57 [==============================] - 19s 332ms/step - loss: 0.1165 - accuracy: 0.9634 - val_loss: 1.9070 - val_accuracy: 0.7318
# Epoch 26/30
# 57/57 [==============================] - 18s 311ms/step - loss: 0.1170 - accuracy: 0.9642 - val_loss: 1.8492 - val_accuracy: 0.7323
# Epoch 27/30
# 57/57 [==============================] - 18s 323ms/step - loss: 0.1166 - accuracy: 0.9634 - val_loss: 1.8758 - val_accuracy: 0.7346
# Epoch 28/30
# 57/57 [==============================] - 18s 308ms/step - loss: 0.1059 - accuracy: 0.9651 - val_loss: 2.0240 - val_accuracy: 0.7162
# Epoch 29/30
# 57/57 [==============================] - 18s 314ms/step - loss: 0.1235 - accuracy: 0.9628 - val_loss: 1.8375 - val_accuracy: 0.7396
# Epoch 30/30
# 57/57 [==============================] - 19s 326ms/step - loss: 0.1128 - accuracy: 0.9645 - val_loss: 1.8471 - val_accuracy: 0.7273

# %% [markdown]
# ### 시각화

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(1 , len(loss) +1)

plt.plot(epochs, loss, 'b--', label='training loss')
plt.plot(epochs, val_loss, 'r:', label='validation loss')
plt.grid()
plt.legend()

plt.figure()
plt.plot(epochs, acc, 'b--', label='training accuracy')
plt.plot(epochs, val_acc, 'r:', label='validation accuracy')
plt.grid()
plt.legend()

plt.show()

# %%
model.evaluate(pad_x_test, y_test)
# Out:
# 71/71 [==============================] - 2s 22ms/step - loss: 1.7646 - accuracy: 0.7106
# [1.7645599842071533, 0.7105966210365295]
